# %% [markdown]
# # Project Documentaion
#
# ## Design brief
# -  Identify a complex societal issue (e.g. housing, natural disasters) or a need within the school
# community. Form a hypothesis related to the issue. Design a system that processes and visualises data to test
# your hypothesis.

# %% [markdown]
# ## Phase 1: Identifying and Defining
#
# ### Mind map
# - Create a three tiered mind map of your question
#
# ![Screenshot 2025-08-20 at 6.00.23 pm.png](<attachment:Screenshot 2025-08-20 at 6.00.23 pm.png>)
#
# ### Define your purpose
# - How does global warming contribute to the increase in the frequency and severity of natural disasters around the world?

# %% [markdown]
# ### Functional requirements
# 1. Data Cleaning
# - Gather both sets of data for the global temperature and the amount of natural disasters
# - Clean data
# 2. Data processing
# - Merge both datasets and calculate the trends over time and analyisis.
# 3. Data visualistion
# - Creating graphs the clearly dipicted then the correltion between the climate change and natural disasters.
# 4. Testing
# - Testing that the question links up to the grpagh that were displayed.
# ### Non functional requiremnets
# 1. Accuracy
# - The dataset have to reilable and able to0 be backedup by acutual evidence.
# 2. Usability
# - Must be easy to use with a wide range of audiences.
# 3. Scalability
# - Should be able to intergate mulitlple other datasets in the furture enblaing the program to expand.

# %% [markdown]
# ## Phase two
# - Findings
